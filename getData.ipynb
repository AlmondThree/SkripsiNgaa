# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews_all, reviews

reviews = reviews_all(
    'id.flip',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df = pd.DataFrame(np.array(reviews),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))

df.head()
#df.info()
#len(df)
# Out:
#                                             reviewId       userName  \
# 0  gp:AOqpTOFOYOU959arOyPaZsoLPun6AcTO4oElhlGWTjL...  anggi saputra
# 1  gp:AOqpTOGSlf9dUBO-lkpcjHlIhcPKpNJiCy72BfhIMJN...     ayu tronix
# 2  gp:AOqpTOGVy7XBnVALRoAxYM1tEIfEjb29ediSCXNrcCI...  Galih Saputra
# 3  gp:AOqpTOGt3GiKSgHkF-ThWfQ29JZvd4RYysSAFFNrdHl...       Ajo aceh
# 4  gp:AOqpTOGGPYpF6IMC7i8I4IiOQiraUd_b2VDzMQDyso_...      Eboy Cell
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                              content  score  thumbsUpCount  \
# 0                                               Nice      5              0
# 1  saya berharap bukti transaksi bisa langsung di...      5              0
# 2                                               Baik      4              0
# 3  aplikasi transfer uang antar bank terbaik dari...      5              0
# 4  Sangat membantu sayang nya di batasi untuk isi...      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0                 None 2022-04-20 21:08:44         None       NaT
# 1                2.3.0 2022-04-20 20:58:11         None       NaT
# 2                2.3.0 2022-04-20 20:57:45         None       NaT
# 3                2.3.0 2022-04-20 20:54:49         None       NaT
# 4                2.3.0 2022-04-20 20:53:42         None       NaT

# %%
df.to_csv('testReview.csv')
